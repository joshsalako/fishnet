# %% [markdown]
# <a href="https://colab.research.google.com/github/joshsalako/fishnet/blob/main/yolo_fishnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
! pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !yolo train model=/content/drive/MyDrive/yolov8l.pt data=/content/drive/MyDrive/Catfish/catfish.yaml epochs=150 imgsz=320 degrees=10 hsv_s=0.4 hsv_v=0.2 fliplr=0.5 dropout=0.1 conf=0.25 flipud=0.5
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo export model=runs/detect/train/weights/best.pt format='torchscript' optimize=True
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (49.6 MB)
#
# TorchScript: starting export with torch 2.0.1+cu118...
# TorchScript: optimizing for mobile...
# TorchScript: export success ✅ 9.5s, saved as 'runs/detect/train/weights/best.torchscript' (98.7 MB)
#
# Export complete (16.8s)
# Results saved to /content/drive/MyDrive/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.torchscript imgsz=640 data=/content/drive/MyDrive/Catfish/catfish.yaml
# Visualize:       https://netron.app

# %%
# !git clone https://github.com/xuarehere/yolovx_deepsort_pytorch.git
# Out:
# Cloning into 'yolovx_deepsort_pytorch'...
# remote: Enumerating objects: 3371, done.
# remote: Counting objects: 100% (3371/3371), done.
# remote: Compressing objects: 100% (2281/2281), done.
# remote: Total 3371 (delta 1172), reused 3206 (delta 1009), pack-reused 0
# Receiving objects: 100% (3371/3371), 33.03 MiB | 27.47 MiB/s, done.
# Resolving deltas: 100% (1172/1172), done.

# %%
# !pip install -r /content/yolovx_deepsort_pytorch/requirements.txt
# Out:
# ...
#   Cloning https://github.com/thomasbrandon/mish-cuda/ (to revision c54271c725d57af62968e960598ffedd4896ef94) to /tmp/pip-install-uvu3dnit/mish-cuda_28c8ac8ed97e43f0929ed55d21dde597
#   Running command git clone --filter=blob:none --quiet https://github.com/thomasbrandon/mish-cuda/ /tmp/pip-install-uvu3dnit/mish-cuda_28c8ac8ed97e43f0929ed55d21dde597
#   Running command git rev-parse -q --verify 'sha^c54271c725d57af62968e960598ffedd4896ef94'
#   Running command git fetch -q https://github.com/thomasbrandon/mish-cuda/ c54271c725d57af62968e960598ffedd4896ef94
#   Resolved https://github.com/thomasbrandon/mish-cuda/ to commit c54271c725d57af62968e960598ffedd4896ef94
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Ignored the following versions that require a different python version: 0.7 Requires-Python >=3.6, <3.7; 0.8 Requires-Python >=3.6, <3.7
# ...

# %%
# !cd detector/YOLOv3/weight/
# !wget https://pjreddie.com/media/files/yolov3.weights
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# !cd ../../../
# Out:
# /bin/bash: line 1: cd: detector/YOLOv3/weight/: No such file or directory
# --2023-08-29 05:12:52--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  82.6MB/s    in 2.9s
#
# 2023-08-29 05:12:55 (82.6 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]
#
# --2023-08-29 05:12:56--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !cd /yolovx_deepsort_pytorch/deep_sort/deep/checkpoint
# !mkdir -p /yolovx_deepsort_pytorch/deep_sort/deep/checkpoint

# %%
# !cp /content/drive/MyDrive/ckpt.t7 /content/yolovx_deepsort_pytorch/deep_sort/deep/checkpoint/
# !cd ../../../

# %%
# !pwd
# Out:
# /content

# %%
# !pip3 install pytorch
# Out:
# ...
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ERROR: Could not build wheels for pytorch, which is required to install pyproject.toml-based projects

# %%
# %cd /content/yolovx_deepsort_pytorch/detector/YOLOv3/nms
# !sh build.sh
# !cd ../../..
# Out:
# /content/yolovx_deepsort_pytorch/detector/YOLOv3/nms
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:398: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 11.8
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'torch_extension' extension
# ...
